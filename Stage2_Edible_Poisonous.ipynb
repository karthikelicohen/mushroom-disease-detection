# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
img_size = (224, 224)
batch_size = 16

train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\karth'

# %%
img_size = (224, 224)
batch_size = 16

train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    "C:/Users/karth/Downloads/archive/splitted_dataset/train",
    target_size=img_size,
    batch_size=batch_size,
    class_mode="binary"
)

val_data = val_gen.flow_from_directory(
    "C:/Users/karth/Downloads/archive/splitted_dataset/val",
    target_size=img_size,
    batch_size=batch_size,
    class_mode="binary"
)

test_data = test_gen.flow_from_directory(
    "C:/Users/karth/Downloads/archive/splitted_dataset/test",
    target_size=img_size,
    batch_size=batch_size,
    class_mode="binary",
    shuffle=False
)
# Out:
# Found 2256 images belonging to 2 classes.
# Found 282 images belonging to 2 classes.
# Found 282 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu")(x)
output = Dense(1, activation="sigmoid")(x)

model2 = Model(inputs=base_model.input, outputs=output)

model2.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model2.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ...

# %%
history2 = model2.fit(
    train_data,
    validation_data=val_data,
    epochs=8
)
# Out:
# C:\Users\karth\anaconda3\envs\mushroom_ai\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/8
# 133/141 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7120 - loss: 0.5750
# C:\Users\karth\anaconda3\envs\mushroom_ai\lib\site-packages\PIL\Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.7141 - loss: 0.5710 - val_accuracy: 0.8617 - val_loss: 0.3616
# Epoch 2/8
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.8880 - loss: 0.2912 - val_accuracy: 0.8794 - val_loss: 0.2930
# Epoch 3/8
# ...

# %%
test_loss, test_acc = model2.evaluate(test_data)
print("Test Accuracy:", test_acc)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9199 - loss: 0.1740
# Test Accuracy: 0.9432623982429504

# %%
model2.save("edible_poisonous_model.h5")
print("Stage 2 model saved successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Stage 2 model saved successfully

# %%
model2.save("edible_poisonous_model.keras")
print("Saved in modern Keras format")
# Out:
# Saved in modern Keras format

# %%
model2 = tf.keras.models.load_model("edible_poisonous_model.h5")
converter2 = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model2 = converter2.convert()

with open("edible_poisonous_model.tflite", "wb") as f:
    f.write(tflite_model2)

print("Stage 2 TFLite saved")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model2 = tf.keras.models.load_model("edible_poisonous_model.h5")
#       2 converter2 = tf.lite.TFLiteConverter.from_keras_model(model2)
#       3 tflite_model2 = converter2.convert()
#
# NameError: name 'tf' is not defined

# %%
import tensorflow as tf

# %%
model2 = tf.keras.models.load_model("edible_poisonous_model.h5")
converter2 = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model2 = converter2.convert()

with open("edible_poisonous_model.tflite", "wb") as f:
    f.write(tflite_model2)

print("Stage 2 TFLite saved")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\karth\AppData\Local\Temp\tmp2dvr68o5\assets
# INFO:tensorflow:Assets written to: C:\Users\karth\AppData\Local\Temp\tmp2dvr68o5\assets
# Saved artifact at 'C:\Users\karth\AppData\Local\Temp\tmp2dvr68o5'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2325949079392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2325949289040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2325949290096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2325949204608: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
